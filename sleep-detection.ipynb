# %% [markdown]
# # Import Data

# %%
# !pip install scikit-learn==1.4.2
# Out:
# Requirement already satisfied: scikit-learn==1.4.2 in c:\users\dell\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\dell\anaconda3\lib\site-packages (from scikit-learn==1.4.2) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\dell\anaconda3\lib\site-packages (from scikit-learn==1.4.2) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dell\anaconda3\lib\site-packages (from scikit-learn==1.4.2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from scikit-learn==1.4.2) (2.2.0)

# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- ------------
# aiobotocore                       2.7.0
# aiohttp                           3.9.3
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.12
# alembic                           1.15.2
# altair                            5.0.1
# anaconda-anon-usage               0.4.3
# anaconda-catalogs                 0.2.0
# anaconda-client                   1.12.3
# anaconda-cloud-auth               0.1.4
# anaconda-navigator                2.5.2
# anaconda-project                  0.11.1
# anyascii                          0.3.2
# anyio                             4.2.0
# appdirs                           1.4.4
# archspec                          0.2.1
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.2.3
# astor                             0.8.1
# astroid                           2.14.2
# astropy                           5.3.4
# asttokens                         2.0.5
# async-lru                         2.0.4
# atomicwrites                      1.4.0
# attrs                             24.2.0
# Automat                           20.2.0
# autopep8                          1.6.0
# Babel                             2.11.0
# backports.functools-lru-cache     1.6.4
# backports.tempfile                1.0
# backports.weakref                 1.0.post1
# bcrypt                            3.2.0
# beautifulsoup4                    4.12.2
# binaryornot                       0.4.4
# black                             23.11.0
# bleach                            4.1.0
# blinker                           1.6.2
# bokeh                             3.3.4
# boltons                           23.0.0
# botocore                          1.31.64
# Bottleneck                        1.3.7
# Brotli                            1.0.9
# cachetools                        4.2.2
# catboost                          1.2.7
# certifi                           2024.2.2
# cffi                              1.16.0
# chardet                           4.0.0
# charset-normalizer                2.0.4
# click                             8.1.7
# cloudpickle                       2.2.1
# clyent                            1.2.2
# colorama                          0.4.6
# colorcet                          3.0.1
# colorlog                          6.9.0
# comm                              0.1.2
# conda                             24.1.2
# conda-build                       24.1.2
# conda-content-trust               0.2.0
# conda_index                       0.4.0
# conda-libmamba-solver             24.1.0
# conda-pack                        0.6.0
# conda-package-handling            2.2.0
# conda_package_streaming           0.9.0
# conda-repo-cli                    1.0.75
# conda-token                       0.4.0
# conda-verify                      3.4.2
# constantly                        23.10.4
# contourpy                         1.2.0
# contractions                      0.1.73
# cookiecutter                      2.5.0
# cryptography                      42.0.2
# cssselect                         1.2.0
# cycler                            0.11.0
# cytoolz                           0.12.2
# dask                              2023.11.0
# datashader                        0.16.0
# debugpy                           1.6.7
# decorator                         5.1.1
# defusedxml                        0.7.1
# diff-match-patch                  20200713
# dill                              0.3.7
# distributed                       2023.11.0
# distro                            1.8.0
# docstring-to-markdown             0.11
# docutils                          0.18.1
# duckdb                            1.1.3
# emoji                             2.14.0
# entrypoints                       0.4
# et-xmlfile                        1.1.0
# executing                         0.8.3
# Faker                             19.13.0
# fastjsonschema                    2.16.2
# filelock                          3.13.1
# flake8                            6.0.0
# Flask                             2.2.5
# fonttools                         4.25.0
# frozenlist                        1.4.0
# fsspec                            2023.10.0
# future                            0.18.3
# gensim                            4.3.0
# gitdb                             4.0.7
# GitPython                         3.1.37
# gmpy2                             2.1.2
# graphviz                          0.20.3
# greenlet                          3.0.1
# h11                               0.14.0
# h5py                              3.9.0
# HeapDict                          1.0.1
# holoviews                         1.18.3
# httpcore                          1.0.6
# httpx                             0.27.2
# huggingface-hub                   0.29.3
# hvplot                            0.9.2
# hyperlink                         21.0.0
# idna                              3.4
# imagecodecs                       2023.1.23
# imageio                           2.33.1
# imagesize                         1.4.1
# imbalanced-learn                  0.11.0
# importlib-metadata                7.0.1
# incremental                       22.10.0
# inflection                        0.5.1
# iniconfig                         1.1.1
# intake                            0.6.8
# intervaltree                      3.1.0
# ipykernel                         6.28.0
# ipython                           8.20.0
# ipython-genutils                  0.2.0
# ipywidgets                        7.6.5
# isort                             5.9.3
# itemadapter                       0.3.0
# itemloaders                       1.1.0
# itsdangerous                      2.0.1
# jaraco.classes                    3.2.1
# jedi                              0.18.1
# jellyfish                         1.0.1
# Jinja2                            3.1.3
# jiter                             0.7.0
# jmespath                          1.0.1
# joblib                            1.2.0
# json5                             0.9.6
# jsonpatch                         1.32
# jsonpointer                       2.1
# jsonschema                        4.19.2
# jsonschema-specifications         2023.7.1
# jupyter                           1.0.0
# jupyter_client                    8.6.0
# jupyter-console                   6.6.3
# jupyter_core                      5.5.0
# jupyter-events                    0.8.0
# jupyter-lsp                       2.2.0
# jupyter_server                    2.10.0
# jupyter_server_terminals          0.4.4
# jupyterlab                        4.0.11
# jupyterlab-pygments               0.1.2
# jupyterlab_server                 2.25.1
# jupyterlab-widgets                3.0.9
# kagglehub                         0.3.4
# keyring                           23.13.1
# kiwisolver                        1.4.4
# lazy_loader                       0.3
# lazy-object-proxy                 1.6.0
# lckr_jupyterlab_variableinspector 3.1.0
# libarchive-c                      2.9
# libmambapy                        1.5.6
# linkify-it-py                     2.0.0
# llvmlite                          0.42.0
# lmdb                              1.4.1
# locket                            1.0.0
# lxml                              4.9.3
# lz4                               4.3.2
# Mako                              1.3.9
# Markdown                          3.4.1
# markdown-it-py                    2.2.0
# MarkupSafe                        2.1.3
# matplotlib                        3.8.0
# matplotlib-inline                 0.1.6
# mccabe                            0.7.0
# mdit-py-plugins                   0.3.0
# mdurl                             0.1.0
# menuinst                          2.0.2
# mistune                           2.0.4
# mkl-fft                           1.3.8
# mkl-random                        1.2.4
# mkl-service                       2.4.0
# more-itertools                    10.1.0
# mpmath                            1.3.0
# msgpack                           1.0.3
# multidict                         6.0.4
# multipledispatch                  0.6.0
# munkres                           1.1.4
# mypy                              1.8.0
# mypy-extensions                   1.0.0
# navigator-updater                 0.4.0
# nbclient                          0.8.0
# nbconvert                         7.10.0
# nbformat                          5.9.2
# nest-asyncio                      1.6.0
# networkx                          3.1
# nltk                              3.8.1
# notebook                          7.0.8
# notebook_shim                     0.2.3
# numba                             0.59.0
# numexpr                           2.8.7
# numpy                             1.26.4
# numpydoc                          1.5.0
# openai                            1.54.1
# opencv-python                     4.10.0.84
# openpyxl                          3.1.5
# optuna                            4.2.1
# outcome                           1.3.0.post0
# overrides                         7.4.0
# packaging                         23.1
# pandas                            2.2.3
# pandasai                          0.1.0
# pandocfilters                     1.5.0
# panel                             1.3.8
# param                             2.0.2
# paramiko                          2.8.1
# parsel                            1.8.1
# parso                             0.8.3
# partd                             1.4.1
# pathlib                           1.0.1
# pathspec                          0.10.3
# patsy                             0.5.3
# pexpect                           4.8.0
# pickleshare                       0.7.5
# pillow                            10.2.0
# pip                               23.3.1
# pkce                              1.0.3
# pkginfo                           1.9.6
# platformdirs                      3.10.0
# plotly                            5.9.0
# pluggy                            1.0.0
# ply                               3.11
# polars                            1.14.0
# prometheus-client                 0.14.1
# prompt-toolkit                    3.0.43
# Protego                           0.1.16
# protobuf                          3.20.3
# psutil                            5.9.0
# ptyprocess                        0.7.0
# pure-eval                         0.2.2
# py-cpuinfo                        9.0.0
# pyahocorasick                     2.1.0
# pyarrow                           14.0.2
# pyasn1                            0.4.8
# pyasn1-modules                    0.2.8
# pycodestyle                       2.10.0
# pycosat                           0.6.6
# pycparser                         2.21
# pyct                              0.5.0
# pycurl                            7.45.2
# pydantic                          1.10.12
# pydeck                            0.8.0
# PyDispatcher                      2.0.5
# pydocstyle                        6.3.0
# pyerfa                            2.0.0
# pyflakes                          3.0.1
# Pygments                          2.15.1
# PyJWT                             2.4.0
# pylint                            2.16.2
# pylint-venv                       2.3.0
# pyls-spyder                       0.4.0
# PyNaCl                            1.5.0
# pyodbc                            5.0.1
# pyOpenSSL                         24.0.0
# pyparsing                         3.0.9
# PyQt5                             5.15.10
# PyQt5-sip                         12.13.0
# PyQtWebEngine                     5.15.6
# pySankey                          0.0.1
# PySocks                           1.7.1
# pytest                            7.4.0
# python-dateutil                   2.8.2
# python-dotenv                     1.0.1
# python-json-logger                2.0.7
# python-lsp-black                  1.2.1
# python-lsp-jsonrpc                1.0.0
# python-lsp-server                 1.7.2
# python-slugify                    5.0.2
# python-snappy                     0.6.1
# pytoolconfig                      1.2.6
# pytz                              2023.3.post1
# pyviz_comms                       3.0.0
# pywavelets                        1.5.0
# pywin32                           305.1
# pywin32-ctypes                    0.2.0
# pywinpty                          2.0.10
# PyYAML                            6.0.1
# pyzmq                             25.1.2
# QDarkStyle                        3.0.2
# qstylizer                         0.2.2
# QtAwesome                         1.2.2
# qtconsole                         5.4.2
# QtPy                              2.4.1
# queuelib                          1.6.2
# referencing                       0.30.2
# regex                             2023.10.3
# requests                          2.31.0
# requests-file                     1.5.1
# requests-toolbelt                 1.0.0
# rfc3339-validator                 0.1.4
# rfc3986-validator                 0.1.1
# rich                              13.3.5
# rope                              1.7.0
# rpds-py                           0.10.6
# Rtree                             1.0.1
# ruamel.yaml                       0.17.21
# ruamel-yaml-conda                 0.17.21
# s3fs                              2023.10.0
# scikit-image                      0.22.0
# scikit-learn                      1.4.2
# scipy                             1.11.4
# Scrapy                            2.8.0
# seaborn                           0.12.2
# selenium                          4.26.1
# semver                            2.13.0
# Send2Trash                        1.8.2
# service-identity                  18.1.0
# setuptools                        68.2.2
# sip                               6.7.12
# six                               1.16.0
# smart-open                        5.2.1
# smmap                             4.0.0
# sniffio                           1.3.0
# snowballstemmer                   2.2.0
# sortedcontainers                  2.4.0
# soupsieve                         2.5
# Sphinx                            5.0.2
# sphinxcontrib-applehelp           1.0.2
# sphinxcontrib-devhelp             1.0.2
# sphinxcontrib-htmlhelp            2.0.0
# sphinxcontrib-jsmath              1.0.1
# sphinxcontrib-qthelp              1.0.3
# sphinxcontrib-serializinghtml     1.1.5
# spyder                            5.4.3
# spyder-kernels                    2.4.4
# SQLAlchemy                        2.0.25
# sqlglot                           25.28.0
# sqlglotrs                         0.2.13
# stack-data                        0.2.0
# statsmodels                       0.14.0
# streamlit                         1.30.0
# sympy                             1.12
# tables                            3.9.2
# tabulate                          0.9.0
# tblib                             1.7.0
# tenacity                          8.2.2
# terminado                         0.17.1
# text-unidecode                    1.3
# textdistance                      4.2.1
# textsearch                        0.0.24
# threadpoolctl                     2.2.0
# three-merge                       0.1.1
# tifffile                          2023.4.12
# tinycss2                          1.2.1
# tldextract                        3.2.0
# toml                              0.10.2
# tomlkit                           0.11.1
# toolz                             0.12.0
# tornado                           6.3.3
# tqdm                              4.65.0
# traitlets                         5.7.1
# trio                              0.27.0
# trio-websocket                    0.11.1
# truststore                        0.8.0
# Twisted                           23.10.0
# twisted-iocpsupport               1.0.2
# typing_extensions                 4.12.2
# tzdata                            2023.3
# tzlocal                           2.1
# uc-micro-py                       1.0.1
# ujson                             5.4.0
# Unidecode                         1.2.0
# urllib3                           2.0.7
# validators                        0.18.2
# w3lib                             2.1.2
# watchdog                          2.1.6
# wcwidth                           0.2.5
# webdriver-manager                 4.0.2
# webencodings                      0.5.1
# websocket-client                  1.8.0
# Werkzeug                          2.2.3
# whatthepatch                      1.0.2
# wheel                             0.41.2
# widgetsnbextension                3.5.2
# win-inet-pton                     1.1.0
# wordcloud                         1.9.4
# wrapt                             1.14.1
# wsproto                           1.2.0
# xarray                            2023.6.0
# xgboost                           2.1.4
# xlrd                              2.0.1
# xlwings                           0.29.1
# xyzservices                       2022.9.0
# yapf                              0.31.0
# yarl                              1.9.3
# zict                              3.0.0
# zipp                              3.17.0
# zope.interface                    5.4.0
# zstandard                         0.19.0

# %%
import numpy as np
import polars as pl
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
from xgboost import XGBClassifier
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore")

# %%
root = '/kaggle/input/child-mind-institute-detect-sleep-states/'
data= pl.read_parquet(root + 'train_series.parquet')
events = pl.read_csv(root + 'train_events.csv')
test = pl.read_parquet(root + 'test_series.parquet')

df=data.clone()
events = events.with_columns([pl.col("step").cast(pl.UInt32).alias("step")])
df1=events.clone()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 root = '/kaggle/input/child-mind-institute-detect-sleep-states/'
# ----> 2 data= pl.read_parquet(root + 'train_series.parquet')
#       3 events = pl.read_csv(root + 'train_events.csv')
#       4 test = pl.read_parquet(root + 'test_series.parquet')
#
# File ~\anaconda3\Lib\site-packages\polars\_utils\deprecation.py:92, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      87 @wraps(function)
#      88 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#      89     _rename_keyword_argument(
#      90         old_name, new_name, kwargs, function.__qualname__, version
#      91     )
# ---> 92     return function(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\polars\_utils\deprecation.py:92, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      87 @wraps(function)
#      88 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#      89     _rename_keyword_argument(
#      90         old_name, new_name, kwargs, function.__qualname__, version
#      91     )
# ---> 92     return function(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\polars\io\parquet\functions.py:241, in read_parquet(source, columns, n_rows, row_index_name, row_index_offset, parallel, use_statistics, hive_partitioning, glob, schema, hive_schema, try_parse_hive_dates, rechunk, low_memory, storage_options, credential_provider, retries, use_pyarrow, pyarrow_options, memory_map, include_file_paths, allow_missing_columns)
#     238     else:
#     239         lf = lf.select(columns)
# --> 241 return lf.collect()
#
# File ~\anaconda3\Lib\site-packages\polars\lazyframe\frame.py:2029, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, streaming, engine, background, _eager, **_kwargs)
#    2027 # Only for testing purposes
#    2028 callback = _kwargs.get("post_opt_callback", callback)
# -> 2029 return wrap_df(ldf.collect(callback))
#
# FileNotFoundError: The system cannot find the path specified. (os error 3): /kaggle/input/child-mind-institute-detect-sleep-states/train_series.parquet

# %%
print(df.head())
print(events.head())
print(test.head())
# Out:
# shape: (5, 5)
# ┌──────────────┬──────┬──────────────────────────┬────────┬────────┐
# │ series_id    ┆ step ┆ timestamp                ┆ anglez ┆ enmo   │
# │ ---          ┆ ---  ┆ ---                      ┆ ---    ┆ ---    │
# │ str          ┆ u32  ┆ str                      ┆ f32    ┆ f32    │
# ╞══════════════╪══════╪══════════════════════════╪════════╪════════╡
# │ 038441c925bb ┆ 0    ┆ 2018-08-14T15:30:00-0400 ┆ 2.6367 ┆ 0.0217 │
# │ 038441c925bb ┆ 1    ┆ 2018-08-14T15:30:05-0400 ┆ 2.6368 ┆ 0.0215 │
# │ 038441c925bb ┆ 2    ┆ 2018-08-14T15:30:10-0400 ┆ 2.637  ┆ 0.0216 │
# │ 038441c925bb ┆ 3    ┆ 2018-08-14T15:30:15-0400 ┆ 2.6368 ┆ 0.0213 │
# │ 038441c925bb ┆ 4    ┆ 2018-08-14T15:30:20-0400 ┆ 2.6368 ┆ 0.0215 │
# └──────────────┴──────┴──────────────────────────┴────────┴────────┘
# shape: (5, 5)
# ┌──────────────┬───────┬────────┬───────┬──────────────────────────┐
# │ series_id    ┆ night ┆ event  ┆ step  ┆ timestamp                │
# │ ---          ┆ ---   ┆ ---    ┆ ---   ┆ ---                      │
# │ str          ┆ i64   ┆ str    ┆ u32   ┆ str                      │
# ╞══════════════╪═══════╪════════╪═══════╪══════════════════════════╡
# │ 038441c925bb ┆ 1     ┆ onset  ┆ 4992  ┆ 2018-08-14T22:26:00-0400 │
# │ 038441c925bb ┆ 1     ┆ wakeup ┆ 10932 ┆ 2018-08-15T06:41:00-0400 │
# │ 038441c925bb ┆ 2     ┆ onset  ┆ 20244 ┆ 2018-08-15T19:37:00-0400 │
# │ 038441c925bb ┆ 2     ┆ wakeup ┆ 27492 ┆ 2018-08-16T05:41:00-0400 │
# │ 038441c925bb ┆ 3     ┆ onset  ┆ 39996 ┆ 2018-08-16T23:03:00-0400 │
# └──────────────┴───────┴────────┴───────┴──────────────────────────┘
# shape: (5, 5)
# ┌──────────────┬──────┬──────────────────────────┬────────┬────────┐
# │ series_id    ┆ step ┆ timestamp                ┆ anglez ┆ enmo   │
# │ ---          ┆ ---  ┆ ---                      ┆ ---    ┆ ---    │
# │ str          ┆ u32  ┆ str                      ┆ f32    ┆ f32    │
# ╞══════════════╪══════╪══════════════════════════╪════════╪════════╡
# │ 038441c925bb ┆ 0    ┆ 2018-08-14T15:30:00-0400 ┆ 2.6367 ┆ 0.0217 │
# │ 038441c925bb ┆ 1    ┆ 2018-08-14T15:30:05-0400 ┆ 2.6368 ┆ 0.0215 │
# │ 038441c925bb ┆ 2    ┆ 2018-08-14T15:30:10-0400 ┆ 2.637  ┆ 0.0216 │
# │ 038441c925bb ┆ 3    ┆ 2018-08-14T15:30:15-0400 ┆ 2.6368 ┆ 0.0213 │
# │ 038441c925bb ┆ 4    ┆ 2018-08-14T15:30:20-0400 ┆ 2.6368 ┆ 0.0215 │
# └──────────────┴──────┴──────────────────────────┴────────┴────────┘

# %% [markdown]
# ## Data Understanding

# %%
print(data)
# Out:
# shape: (127_946_340, 5)
# ┌──────────────┬────────┬──────────────────────────┬────────────┬────────┐
# │ series_id    ┆ step   ┆ timestamp                ┆ anglez     ┆ enmo   │
# │ ---          ┆ ---    ┆ ---                      ┆ ---        ┆ ---    │
# │ str          ┆ u32    ┆ str                      ┆ f32        ┆ f32    │
# ╞══════════════╪════════╪══════════════════════════╪════════════╪════════╡
# │ 038441c925bb ┆ 0      ┆ 2018-08-14T15:30:00-0400 ┆ 2.6367     ┆ 0.0217 │
# │ 038441c925bb ┆ 1      ┆ 2018-08-14T15:30:05-0400 ┆ 2.6368     ┆ 0.0215 │
# │ 038441c925bb ┆ 2      ┆ 2018-08-14T15:30:10-0400 ┆ 2.637      ┆ 0.0216 │
# │ 038441c925bb ┆ 3      ┆ 2018-08-14T15:30:15-0400 ┆ 2.6368     ┆ 0.0213 │
# │ 038441c925bb ┆ 4      ┆ 2018-08-14T15:30:20-0400 ┆ 2.6368     ┆ 0.0215 │
# │ …            ┆ …      ┆ …                        ┆ …          ┆ …      │
# │ fe90110788d2 ┆ 592375 ┆ 2017-09-08T00:14:35-0400 ┆ -27.2775   ┆ 0.0204 │
# │ fe90110788d2 ┆ 592376 ┆ 2017-09-08T00:14:40-0400 ┆ -27.032499 ┆ 0.0233 │
# │ fe90110788d2 ┆ 592377 ┆ 2017-09-08T00:14:45-0400 ┆ -26.8412   ┆ 0.0202 │
# │ fe90110788d2 ┆ 592378 ┆ 2017-09-08T00:14:50-0400 ┆ -26.7239   ┆ 0.0199 │
# │ fe90110788d2 ┆ 592379 ┆ 2017-09-08T00:14:55-0400 ┆ -31.521601 ┆ 0.0205 │
# └──────────────┴────────┴──────────────────────────┴────────────┴────────┘

# %% [markdown]
# **Train Series Data**
#
# This dataset contains accelerometer readings collected every 5 seconds. The columns are:
#
#
# - series_id → Unique identifier for each device (or individual data recording session).
# - step → Represents the time step, where each step increases every 5 seconds.
#
# - timestamp → The actual date and time when the data was recorded.
#
# - anglez → Indicates the orientation of the hand/arm (derived from accelerometer axes, used to understand posture).
#
# - enmo (Euclidean Norm Minus One )→ a metric used to measure physical activity. Lower ENMO values indicate inactivity and help detect sleep periods.

# %%
print(events)
# Out:
# shape: (14_508, 5)
# ┌──────────────┬───────┬────────┬────────┬──────────────────────────┐
# │ series_id    ┆ night ┆ event  ┆ step   ┆ timestamp                │
# │ ---          ┆ ---   ┆ ---    ┆ ---    ┆ ---                      │
# │ str          ┆ i64   ┆ str    ┆ u32    ┆ str                      │
# ╞══════════════╪═══════╪════════╪════════╪══════════════════════════╡
# │ 038441c925bb ┆ 1     ┆ onset  ┆ 4992   ┆ 2018-08-14T22:26:00-0400 │
# │ 038441c925bb ┆ 1     ┆ wakeup ┆ 10932  ┆ 2018-08-15T06:41:00-0400 │
# │ 038441c925bb ┆ 2     ┆ onset  ┆ 20244  ┆ 2018-08-15T19:37:00-0400 │
# │ 038441c925bb ┆ 2     ┆ wakeup ┆ 27492  ┆ 2018-08-16T05:41:00-0400 │
# │ 038441c925bb ┆ 3     ┆ onset  ┆ 39996  ┆ 2018-08-16T23:03:00-0400 │
# │ …            ┆ …     ┆ …      ┆ …      ┆ …                        │
# │ fe90110788d2 ┆ 33    ┆ wakeup ┆ 560604 ┆ 2017-09-06T04:07:00-0400 │
# │ fe90110788d2 ┆ 34    ┆ onset  ┆ 574620 ┆ 2017-09-06T23:35:00-0400 │
# │ fe90110788d2 ┆ 34    ┆ wakeup ┆ 581604 ┆ 2017-09-07T09:17:00-0400 │
# │ fe90110788d2 ┆ 35    ┆ onset  ┆ null   ┆ null                     │
# │ fe90110788d2 ┆ 35    ┆ wakeup ┆ null   ┆ null                     │
# └──────────────┴───────┴────────┴────────┴──────────────────────────┘

# %% [markdown]
# **Train Events Data**<br>
# This dataset represents sleep-related events (onset and wakeup) for each individual series.
#
# series_id → Identifier for the individual accelerometer device
#
# night → Indicates the night number (useful for separating multiple days of recordings).
#
# event → Type of sleep event, either onset (sleep start) or wakeup (sleep end).
#
# step → The time step (aligned with train_series) at which the event occurred. Each step represents 5 seconds.
#
# timestamp → The actual date and time when the event was recorded.

# %% [markdown]
# **Some More information about the data**
#
# **1. A single sleep period must be at least 30 minutes in length**
# A sleep episode will only be considered valid if it lasts at least 30 minutes continuously.
#
# Short naps or dozing off for less than 30 minutes are not recorded as sleep events.
#
# **2. A single sleep period can be interrupted by bouts of activity that do not exceed 30 consecutive minutes** <br>
# If a person wakes up or moves around briefly during sleep but for less than 30 minutes, it's still considered one continuous sleep.
#
# Example: If someone sleeps from 10 PM to 6 AM but moves from 2:00 to 2:20 AM, it's still treated as one sleep session.
#
# **3. No sleep windows can be detected unless the watch is deemed to be worn for the duration**<br>
# If the accelerometer is not worn during the night, sleep cannot be recorded, even if the person was actually sleeping.
#
# This is determined based on very little variation in movement, which suggests the device was removed, not that the person was inactive.
#
# **4. The longest sleep window during the night is the only one which is recorded**<br>
# If a person takes multiple naps or sleep sessions, only the longest one is considered for the night.
#
# This is to simplify and focus on the main sleep period, which usually occurs at night.
#
# **5. If no valid sleep window is identifiable, neither an onset nor a wakeup event is recorded for that night**<br>
# If the data does not show a valid sleep pattern, then no events (neither sleep start nor wake-up) are logged for that night.
#
# This can happen due to poor data quality, device not being worn, or no valid sleep detected.
#
# **6. Sleep events do not need to straddle the day-line**<br>
# A sleep session doesn't have to cross midnight to be considered valid.
#
# Example: You can have one from 01:00–06:00 AM, and another from 7:00 PM–11:30 PM on the same calendar day, and they can still be considered sleep for two different nights.
#
# **7. There are roughly as many nights recorded for a series as there are 24-hour periods in that series**<br>
# If the device was recording for 10 days, expect about 10 nights of sleep data — assuming valid sleep is detected each night.

# %% [markdown]
# ## Train Series Analysis

# %%
df = df.with_columns([
        pl.col('timestamp').str.slice(0, 19).str.strptime(pl.Datetime, format="%Y-%m-%dT%H:%M:%S")
        .alias('timestamp_datetime')]).with_columns([
            pl.col('timestamp_datetime').dt.date().alias('date'),
            pl.col('timestamp_datetime').dt.hour().alias('hour')])


df=df.drop(["timestamp","timestamp_datetime"])
df
# Out:
# shape: (127_946_340, 6)
# ┌──────────────┬────────┬────────────┬────────┬────────────┬──────┐
# │ series_id    ┆ step   ┆ anglez     ┆ enmo   ┆ date       ┆ hour │
# │ ---          ┆ ---    ┆ ---        ┆ ---    ┆ ---        ┆ ---  │
# │ str          ┆ u32    ┆ f32        ┆ f32    ┆ date       ┆ i8   │
# ╞══════════════╪════════╪════════════╪════════╪════════════╪══════╡
# │ 038441c925bb ┆ 0      ┆ 2.6367     ┆ 0.0217 ┆ 2018-08-14 ┆ 15   │
# │ 038441c925bb ┆ 1      ┆ 2.6368     ┆ 0.0215 ┆ 2018-08-14 ┆ 15   │
# │ 038441c925bb ┆ 2      ┆ 2.637      ┆ 0.0216 ┆ 2018-08-14 ┆ 15   │
# │ 038441c925bb ┆ 3      ┆ 2.6368     ┆ 0.0213 ┆ 2018-08-14 ┆ 15   │
# │ 038441c925bb ┆ 4      ┆ 2.6368     ┆ 0.0215 ┆ 2018-08-14 ┆ 15   │
# │ …            ┆ …      ┆ …          ┆ …      ┆ …          ┆ …    │
# │ fe90110788d2 ┆ 592375 ┆ -27.2775   ┆ 0.0204 ┆ 2017-09-08 ┆ 0    │
# │ fe90110788d2 ┆ 592376 ┆ -27.032499 ┆ 0.0233 ┆ 2017-09-08 ┆ 0    │
# │ fe90110788d2 ┆ 592377 ┆ -26.8412   ┆ 0.0202 ┆ 2017-09-08 ┆ 0    │
# │ fe90110788d2 ┆ 592378 ┆ -26.7239   ┆ 0.0199 ┆ 2017-09-08 ┆ 0    │
# │ fe90110788d2 ┆ 592379 ┆ -31.521601 ┆ 0.0205 ┆ 2017-09-08 ┆ 0    │
# └──────────────┴────────┴────────────┴────────┴────────────┴──────┘

# %%
df['series_id'].n_unique()
# Out:
# 277

# %% [markdown]
# There are total 277 individuals are there

# %%
df['date'].describe()
# Out:
# shape: (8, 2)
# ┌────────────┬────────────────────────────┐
# │ statistic  ┆ value                      │
# │ ---        ┆ ---                        │
# │ str        ┆ str                        │
# ╞════════════╪════════════════════════════╡
# │ count      ┆ 127946340                  │
# │ null_count ┆ 0                          │
# │ mean       ┆ 2018-07-16 01:30:41.593000 │
# │ min        ┆ 2017-08-04                 │
# │ 25%        ┆ 2018-02-12                 │
# │ 50%        ┆ 2018-07-22                 │
# │ 75%        ┆ 2018-12-24                 │
# │ max        ┆ 2019-07-09                 │
# └────────────┴────────────────────────────┘

# %% [markdown]
# - The statistical distribution of date is indicating the data was collected from **August 4, 2017**, to **July 9, 2019**, spanning approximately **2 years**.

# %%
df_copy=df['date'].to_pandas().dt.year

# %%
df_copy.value_counts()
sns.barplot(x=df_copy.value_counts().index,y=df_copy.value_counts().values)
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# The plot shows that the majority of the data was collected during the year 2018. There is a noticeable drop in data volume at both the beginning and end of the time range. This pattern may indicate that data collection started gradually and tapered off toward the end. It is also possible that many individuals discontinued data generation over time, leading to reduced activity outside the peak period.

# %%
df['enmo'].describe()
# Out:
# shape: (9, 2)
# ┌────────────┬─────────────┐
# │ statistic  ┆ value       │
# │ ---        ┆ ---         │
# │ str        ┆ f64         │
# ╞════════════╪═════════════╡
# │ count      ┆ 1.2794634e8 │
# │ null_count ┆ 0.0         │
# │ mean       ┆ 0.041315    │
# │ std        ┆ 0.101829    │
# │ min        ┆ 0.0         │
# │ 25%        ┆ 0.0013      │
# │ 50%        ┆ 0.0172      │
# │ 75%        ┆ 0.0437      │
# │ max        ┆ 11.4337     │
# └────────────┴─────────────┘

# %% [markdown]
# **Formula for enmo value is:**<br>
# ![image.png](attachment:d289890f-3b36-409b-94c8-f7bfebeea05f.png)
#
# - It measures overall movement, with higher values indicating more activity.
#
# If we abserve clearly the enmo values are ranges from 0 to 11.4337

# %%
a=df.to_pandas()
a
# Out:
#               series_id    step     anglez    enmo       date  hour
# 0          038441c925bb       0   2.636700  0.0217 2018-08-14    15
# 1          038441c925bb       1   2.636800  0.0215 2018-08-14    15
# 2          038441c925bb       2   2.637000  0.0216 2018-08-14    15
# 3          038441c925bb       3   2.636800  0.0213 2018-08-14    15
# 4          038441c925bb       4   2.636800  0.0215 2018-08-14    15
# ...                 ...     ...        ...     ...        ...   ...
# 127946335  fe90110788d2  592375 -27.277500  0.0204 2017-09-08     0
# 127946336  fe90110788d2  592376 -27.032499  0.0233 2017-09-08     0
# 127946337  fe90110788d2  592377 -26.841200  0.0202 2017-09-08     0
# 127946338  fe90110788d2  592378 -26.723900  0.0199 2017-09-08     0
# 127946339  fe90110788d2  592379 -31.521601  0.0205 2017-09-08     0
#
# [127946340 rows x 6 columns]

# %%
b=a.groupby('hour')['enmo'].count()
sns.lineplot(x=b.index,y=b.values)
# Out:
# <Axes: xlabel='hour'>

# %% [markdown]
# **Enmo Values Pattern by time**<br>
# Observing the trend in ENMO values across the day, we notice a clear dip around hour 10, indicating a period of low activity. Following this low point, there's a significant and rapid increase in ENMO values, peaking around hour 18. This suggests a substantial rise in activity levels between these hours.

# %%
top_steps = a.groupby('series_id')['step'].max().sort_values(ascending=False).head()
bottom_steps = a.groupby('series_id')['step'].max().sort_values(ascending=True).head()

fig, axs = plt.subplots(1, 2, figsize=(12, 6))

axs[0].bar(top_steps.index, top_steps.values, color='blue')
axs[0].set_title("Top 5 Steps")
axs[0].set_xlabel("Series ID")
axs[0].set_ylabel("Step Value")
axs[0].tick_params(axis='x', rotation=45)

axs[1].bar(bottom_steps.index, bottom_steps.values, color='orange')
axs[1].set_title("Bottom 5 Steps")
axs[1].set_xlabel("Series ID")
axs[1].set_ylabel("Step Value")
axs[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Top–Bottom People Time Pattern**<br>
# **First plot**: These individuals have the highest step counts, indicating they are using the accumulators for longer durations compared to others.(here 1.4 - 1.4 million)
#
# **Second plot**: These individuals have the lowest step counts, suggesting they use the accumulators for shorter durations compared to the rest.

# %% [markdown]
# hand position based ont the anglez value
#
# ![anglez positions.png](attachment:9da31a82-fdf5-4ce0-b114-92ee950adc36.png)
#
# **Formula of the anglez value is:**
#
# ![image.png](attachment:6989d533-c961-4dee-bf9a-81208ff76fce.png)
#
# - It measures arm orientation relative to gravity (up/down tilt).
#
#
# **What are x, y, z in ENMO and AngleZ?**<br>
# x: Acceleration in the lateral direction (side-to-side).
#
# y: Acceleration in the forward-backward direction (along the body).
#
# z: Acceleration in the vertical direction (toward the sky or ground, depending on orientation).

# %%
b=a['anglez'].value_counts()
b.index=b.index.round()
b=pd.DataFrame({
    "anglez": b.index,
    "count": b.values
}).groupby("anglez")['count'].sum()


plt.figure(figsize=(25, 12)) 
sns.barplot(x=b.index, y=b.values, color='orange')

plt.xticks(rotation=90)  
plt.tight_layout()
plt.show()

# %% [markdown]
# **Anglez data distribution**<br>
# - Based on this, the anglez count distribution is bell-shaped, indicating it follows a normal distribution with a slight right skew. One key observation is that the anglez value of 0 occurs significantly more often compared to other values, suggesting that most individuals' hand positions are at rest.
#
# - Furthermore, between anglez values of -84 to -89, there is an increase in anglez values, which corresponds to a shift in the hand position.

# %%
a=df.to_pandas()
a
# Out:
#               series_id    step     anglez    enmo       date  hour
# 0          038441c925bb       0   2.636700  0.0217 2018-08-14    15
# 1          038441c925bb       1   2.636800  0.0215 2018-08-14    15
# 2          038441c925bb       2   2.637000  0.0216 2018-08-14    15
# 3          038441c925bb       3   2.636800  0.0213 2018-08-14    15
# 4          038441c925bb       4   2.636800  0.0215 2018-08-14    15
# ...                 ...     ...        ...     ...        ...   ...
# 127946335  fe90110788d2  592375 -27.277500  0.0204 2017-09-08     0
# 127946336  fe90110788d2  592376 -27.032499  0.0233 2017-09-08     0
# 127946337  fe90110788d2  592377 -26.841200  0.0202 2017-09-08     0
# 127946338  fe90110788d2  592378 -26.723900  0.0199 2017-09-08     0
# 127946339  fe90110788d2  592379 -31.521601  0.0205 2017-09-08     0
#
# [127946340 rows x 6 columns]

# %%
b=a['enmo'].value_counts()
b.index=b.index.round(2)
b=pd.DataFrame({
    "enmo": b.index,
    "count": b.values
})

b=b[b['enmo']<1]
b=b.groupby("enmo")['count'].sum()
plt.figure(figsize=(25, 12)) 
sns.barplot(x=b.index, y=b.values, color='orange')

plt.xticks(rotation=90)  
plt.tight_layout()
plt.show()

# %% [markdown]
# **Enmo Values distribution**
#
# - The ENMO distribution is highly right-skewed and follows a log-normal pattern, with most values clustered near 0.00, indicating long periods of inactivity or sleep.
#
# - The ENMO value "0.00" dominates the distribution, meaning most individuals are at rest for a significant portion of time.
#
# - ENMO values starting from 0.70 onward appear consistently, suggesting these are not outliers, but periods of high activity seen across different individuals.
#
# - The gradual decrease from low to high ENMO bins reflects natural human activity, with rest being most frequent, followed by light and moderate movements, and fewer intense activity bursts.

# %% [markdown]
# ## Events Data Analysis

# %%
print(df1)
print("No of individuals :",df1['series_id'].n_unique())
# Out:
# shape: (14_508, 5)
# ┌──────────────┬───────┬────────┬────────┬──────────────────────────┐
# │ series_id    ┆ night ┆ event  ┆ step   ┆ timestamp                │
# │ ---          ┆ ---   ┆ ---    ┆ ---    ┆ ---                      │
# │ str          ┆ i64   ┆ str    ┆ u32    ┆ str                      │
# ╞══════════════╪═══════╪════════╪════════╪══════════════════════════╡
# │ 038441c925bb ┆ 1     ┆ onset  ┆ 4992   ┆ 2018-08-14T22:26:00-0400 │
# │ 038441c925bb ┆ 1     ┆ wakeup ┆ 10932  ┆ 2018-08-15T06:41:00-0400 │
# │ 038441c925bb ┆ 2     ┆ onset  ┆ 20244  ┆ 2018-08-15T19:37:00-0400 │
# │ 038441c925bb ┆ 2     ┆ wakeup ┆ 27492  ┆ 2018-08-16T05:41:00-0400 │
# │ 038441c925bb ┆ 3     ┆ onset  ┆ 39996  ┆ 2018-08-16T23:03:00-0400 │
# │ …            ┆ …     ┆ …      ┆ …      ┆ …                        │
# │ fe90110788d2 ┆ 33    ┆ wakeup ┆ 560604 ┆ 2017-09-06T04:07:00-0400 │
# │ fe90110788d2 ┆ 34    ┆ onset  ┆ 574620 ┆ 2017-09-06T23:35:00-0400 │
# │ fe90110788d2 ┆ 34    ┆ wakeup ┆ 581604 ┆ 2017-09-07T09:17:00-0400 │
# │ fe90110788d2 ┆ 35    ┆ onset  ┆ null   ┆ null                     │
# │ fe90110788d2 ┆ 35    ┆ wakeup ┆ null   ┆ null                     │
# └──────────────┴───────┴────────┴────────┴──────────────────────────┘
# No of individuals : 277

# %% [markdown]
# - There are a total of 277 individuals, meaning this data has been collected from the raw accumulators of 277 individuals.

# %%
print(df1)
# Out:
# shape: (14_508, 5)
# ┌──────────────┬───────┬────────┬────────┬──────────────────────────┐
# │ series_id    ┆ night ┆ event  ┆ step   ┆ timestamp                │
# │ ---          ┆ ---   ┆ ---    ┆ ---    ┆ ---                      │
# │ str          ┆ i64   ┆ str    ┆ u32    ┆ str                      │
# ╞══════════════╪═══════╪════════╪════════╪══════════════════════════╡
# │ 038441c925bb ┆ 1     ┆ onset  ┆ 4992   ┆ 2018-08-14T22:26:00-0400 │
# │ 038441c925bb ┆ 1     ┆ wakeup ┆ 10932  ┆ 2018-08-15T06:41:00-0400 │
# │ 038441c925bb ┆ 2     ┆ onset  ┆ 20244  ┆ 2018-08-15T19:37:00-0400 │
# │ 038441c925bb ┆ 2     ┆ wakeup ┆ 27492  ┆ 2018-08-16T05:41:00-0400 │
# │ 038441c925bb ┆ 3     ┆ onset  ┆ 39996  ┆ 2018-08-16T23:03:00-0400 │
# │ …            ┆ …     ┆ …      ┆ …      ┆ …                        │
# │ fe90110788d2 ┆ 33    ┆ wakeup ┆ 560604 ┆ 2017-09-06T04:07:00-0400 │
# │ fe90110788d2 ┆ 34    ┆ onset  ┆ 574620 ┆ 2017-09-06T23:35:00-0400 │
# │ fe90110788d2 ┆ 34    ┆ wakeup ┆ 581604 ┆ 2017-09-07T09:17:00-0400 │
# │ fe90110788d2 ┆ 35    ┆ onset  ┆ null   ┆ null                     │
# │ fe90110788d2 ┆ 35    ┆ wakeup ┆ null   ┆ null                     │
# └──────────────┴───────┴────────┴────────┴──────────────────────────┘

# %%
df1.to_pandas().duplicated().sum()
# means there is no duplicated values
# Out:
# 0

# %% [markdown]
# ## Events missing Values Handling

# %%
df1.to_pandas().isna().sum()
# Out:
# series_id       0
# night           0
# event           0
# step         4923
# timestamp    4923
# dtype: int64

# %%
a=df1.pivot(index=['series_id','night'],columns='event',values='step').to_pandas()
a
# Out:
#          series_id  night     onset    wakeup
# 0     038441c925bb      1    4992.0   10932.0
# 1     038441c925bb      2   20244.0   27492.0
# 2     038441c925bb      3   39996.0   44400.0
# 3     038441c925bb      4   57240.0   62856.0
# 4     038441c925bb      5       NaN       NaN
# ...            ...    ...       ...       ...
# 7249  fe90110788d2     31  522852.0  529104.0
# 7250  fe90110788d2     32  538956.0  547152.0
# 7251  fe90110788d2     33  556560.0  560604.0
# 7252  fe90110788d2     34  574620.0  581604.0
# 7253  fe90110788d2     35       NaN       NaN
#
# [7254 rows x 4 columns]

# %%
b=a[(a['onset'].isna() & a['wakeup'].notna()) | (a['onset'].notna() & a['wakeup'].isna())]
b
# Out:
#          series_id  night     onset    wakeup
# 279   0ce74d6d2106     20  332376.0       NaN
# 712   154fe824ed87     30       NaN  514980.0
# 1939  44a41bba1ee7     10       NaN  165684.0
# 6776  efbfc4526d58      7       NaN  114864.0
# 7052  f8a8da8bdd00     17       NaN  291384.0

# %%
for i,j in zip(b['series_id'],b['night']):
    print(i,j)
    df1=df1.with_columns(
        pl.when((pl.col('series_id') == i) & (pl.col('night') == j)).then(None).otherwise(pl.col('step')).alias('step'),
        pl.when((pl.col('series_id') == i) & (pl.col('night') == j)).then(None).otherwise(pl.col('timestamp')).alias('timestamp')
    )
# Out:
# 0ce74d6d2106 20
# 154fe824ed87 30
# 44a41bba1ee7 10
# efbfc4526d58 7
# f8a8da8bdd00 17

# %%
a=df1.pivot(index=['series_id','night'],columns='event',values='step').to_pandas()
b=a[(a['onset'].isna() & a['wakeup'].notna()) | (a['onset'].notna() & a['wakeup'].isna())]
b
# Out:
# Empty DataFrame
# Columns: [series_id, night, onset, wakeup]
# Index: []

# %%
df1.to_pandas().isna().sum()
# Out:
# series_id       0
# night           0
# event           0
# step         4928
# timestamp    4928
# dtype: int64

# %%
df1=(df1.filter(~(pl.col("timestamp").is_null() & pl.col("step").is_null())))
print(df1.head())
# Out:
# shape: (5, 5)
# ┌──────────────┬───────┬────────┬───────┬──────────────────────────┐
# │ series_id    ┆ night ┆ event  ┆ step  ┆ timestamp                │
# │ ---          ┆ ---   ┆ ---    ┆ ---   ┆ ---                      │
# │ str          ┆ i64   ┆ str    ┆ u32   ┆ str                      │
# ╞══════════════╪═══════╪════════╪═══════╪══════════════════════════╡
# │ 038441c925bb ┆ 1     ┆ onset  ┆ 4992  ┆ 2018-08-14T22:26:00-0400 │
# │ 038441c925bb ┆ 1     ┆ wakeup ┆ 10932 ┆ 2018-08-15T06:41:00-0400 │
# │ 038441c925bb ┆ 2     ┆ onset  ┆ 20244 ┆ 2018-08-15T19:37:00-0400 │
# │ 038441c925bb ┆ 2     ┆ wakeup ┆ 27492 ┆ 2018-08-16T05:41:00-0400 │
# │ 038441c925bb ┆ 3     ┆ onset  ┆ 39996 ┆ 2018-08-16T23:03:00-0400 │
# └──────────────┴───────┴────────┴───────┴──────────────────────────┘

# %%
df1.to_pandas().isna().sum()
# Out:
# series_id    0
# night        0
# event        0
# step         0
# timestamp    0
# dtype: int64

# %%
df1['event'].to_pandas().value_counts()
# Out:
# event
# onset     4790
# wakeup    4790
# Name: count, dtype: int64

# %%
a=df1.to_pandas()
a=a.groupby("series_id")['night'].max().sort_values(ascending=False)
plt.figure(figsize=(70, 10))  
sns.barplot(x=a.index, y=a.values) 
plt.xticks(rotation=90)  
plt.show()

# %% [markdown]
# - The individual with enc_id **78569a801a38** has contributed the highest number of nights of data, indicating consistent and prolonged device usage or tracking — significantly more than others.
#
# - The distribution is right-skewed, meaning only a few individuals have high night-level data, while most individuals have moderate to low night-level records, potentially due to early drop-off, incomplete tracking, or shorter study duration.

# %%
df1 = df1.with_columns([
        pl.col('timestamp').str.slice(0, 19).str.strptime(pl.Datetime, format="%Y-%m-%dT%H:%M:%S")
        .alias('timestamp_datetime')]).with_columns([
            pl.col('timestamp_datetime').dt.date().alias('date'),
            pl.col('timestamp_datetime').dt.hour().alias('hour')])
df1=df1.drop(["timestamp","timestamp_datetime"])

# %%
a=df1.pivot(index=['series_id', 'night'], columns='event', values='hour').to_pandas()
a
# Out:
#          series_id  night  onset  wakeup
# 0     038441c925bb      1     22       6
# 1     038441c925bb      2     19       5
# 2     038441c925bb      3     23       5
# 3     038441c925bb      4     23       6
# 4     038441c925bb      6     22       7
# ...            ...    ...    ...     ...
# 4785  fe90110788d2     30     23       7
# 4786  fe90110788d2     31     23       8
# 4787  fe90110788d2     32     22       9
# 4788  fe90110788d2     33     22       4
# 4789  fe90110788d2     34     23       9
#
# [4790 rows x 4 columns]

# %%
a['sleep_hours'] = np.where(
    a['wakeup'] >= a['onset'],
    a['wakeup'] - a['onset'],        
    (24 - a['onset']) + a['wakeup'])

# %%
a
# Out:
#          series_id  night  onset  wakeup  sleep_hours
# 0     038441c925bb      1     22       6            8
# 1     038441c925bb      2     19       5           10
# 2     038441c925bb      3     23       5            6
# 3     038441c925bb      4     23       6            7
# 4     038441c925bb      6     22       7            9
# ...            ...    ...    ...     ...          ...
# 4785  fe90110788d2     30     23       7            8
# 4786  fe90110788d2     31     23       8            9
# 4787  fe90110788d2     32     22       9           11
# 4788  fe90110788d2     33     22       4            6
# 4789  fe90110788d2     34     23       9           10
#
# [4790 rows x 5 columns]

# %%
a.to_csv("Sleep_patterns.csv")

# %%
s_id=np.random.choice(np.array(df1['series_id'].unique()))
b=a.loc[a['series_id']==s_id,["night",'sleep_hours']]

print(f"Id {s_id} sleep pattern :")
plt.figure(figsize=(20, 10))
sns.barplot(x=b['night'],y=b['sleep_hours'])
# Out:
# Id ad425f3ee76d sleep pattern :
# <Axes: xlabel='night', ylabel='sleep_hours'>

# %% [markdown]
# **Individual's Sleep Pattern**<br>
# Understanding a person's sleep pattern helps us determine whether they are following a healthy routine.
# - If they are not, it may increase their risk of health issues.
# - Sleeping too little can be harmful, but oversleeping can also lead to problems such as increased fatigue and laziness.

# %%
data_1 = df.join(df1[['series_id', 'step', 'event']], on=['series_id', 'step'], how='inner').sort(by=['series_id', 'step'])
data_1
# Out:
# shape: (9_580, 7)
# ┌──────────────┬────────┬────────────┬────────┬────────────┬──────┬────────┐
# │ series_id    ┆ step   ┆ anglez     ┆ enmo   ┆ date       ┆ hour ┆ event  │
# │ ---          ┆ ---    ┆ ---        ┆ ---    ┆ ---        ┆ ---  ┆ ---    │
# │ str          ┆ u32    ┆ f32        ┆ f32    ┆ date       ┆ i8   ┆ str    │
# ╞══════════════╪════════╪════════════╪════════╪════════════╪══════╪════════╡
# │ 038441c925bb ┆ 4992   ┆ -78.690598 ┆ 0.0099 ┆ 2018-08-14 ┆ 22   ┆ onset  │
# │ 038441c925bb ┆ 10932  ┆ -61.578201 ┆ 0.0263 ┆ 2018-08-15 ┆ 6    ┆ wakeup │
# │ 038441c925bb ┆ 20244  ┆ -6.3874    ┆ 0.0182 ┆ 2018-08-15 ┆ 19   ┆ onset  │
# │ 038441c925bb ┆ 27492  ┆ -45.355099 ┆ 0.0165 ┆ 2018-08-16 ┆ 5    ┆ wakeup │
# │ 038441c925bb ┆ 39996  ┆ -1.7867    ┆ 0.0    ┆ 2018-08-16 ┆ 23   ┆ onset  │
# │ …            ┆ …      ┆ …          ┆ …      ┆ …          ┆ …    ┆ …      │
# │ fe90110788d2 ┆ 547152 ┆ -56.768902 ┆ 0.0042 ┆ 2017-09-05 ┆ 9    ┆ wakeup │
# │ fe90110788d2 ┆ 556560 ┆ -16.5867   ┆ 0.0    ┆ 2017-09-05 ┆ 22   ┆ onset  │
# │ fe90110788d2 ┆ 560604 ┆ -43.0509   ┆ 0.0    ┆ 2017-09-06 ┆ 4    ┆ wakeup │
# │ fe90110788d2 ┆ 574620 ┆ 1.5191     ┆ 0.0066 ┆ 2017-09-06 ┆ 23   ┆ onset  │
# │ fe90110788d2 ┆ 581604 ┆ 79.053802  ┆ 0.0    ┆ 2017-09-07 ┆ 9    ┆ wakeup │
# └──────────────┴────────┴────────────┴────────┴────────────┴──────┴────────┘

# %% [markdown]
# If we look here, there are a total of six features. However, based on general knowledge, it's not necessary to use all of them for training the model. Therefore, I will select only two input features: anglez and enmo.

# %%
data_1=data_1[['anglez','enmo','event']]

# %%
data_1
# Out:
# shape: (9_580, 3)
# ┌────────────┬────────┬────────┐
# │ anglez     ┆ enmo   ┆ event  │
# │ ---        ┆ ---    ┆ ---    │
# │ f32        ┆ f32    ┆ str    │
# ╞════════════╪════════╪════════╡
# │ -78.690598 ┆ 0.0099 ┆ onset  │
# │ -61.578201 ┆ 0.0263 ┆ wakeup │
# │ -6.3874    ┆ 0.0182 ┆ onset  │
# │ -45.355099 ┆ 0.0165 ┆ wakeup │
# │ -1.7867    ┆ 0.0    ┆ onset  │
# │ …          ┆ …      ┆ …      │
# │ -56.768902 ┆ 0.0042 ┆ wakeup │
# │ -16.5867   ┆ 0.0    ┆ onset  │
# │ -43.0509   ┆ 0.0    ┆ wakeup │
# │ 1.5191     ┆ 0.0066 ┆ onset  │
# │ 79.053802  ┆ 0.0    ┆ wakeup │
# └────────────┴────────┴────────┘

# %%
corr_matrix = (data_1.to_pandas()).select_dtypes(include='number').corr()

# Now plot the heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# **Relation Ship between Features**<br>
# If we observe here there is very less negative relation ship is there between these two input features anglez and enmo

# %%
sns.scatterplot(x=data_1['anglez'],y=data_1['enmo'],hue=data_1['event'])
# Out:
# <Axes: xlabel='anglez', ylabel='enmo'>

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
anglez_scaled = scaler.fit_transform(data_1[['anglez']]).reshape(1,-1)[0]

# %%
sns.scatterplot(x=anglez_scaled,y=data_1['enmo'],hue=data_1['event'])
# Out:
# <Axes: ylabel='enmo'>

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
anglez_scaled = scaler.fit_transform(data_1[['anglez']]).reshape(1,-1)[0]

# %%
sns.scatterplot(x=anglez_scaled,y=data_1['enmo'],hue=data_1['event'])
# Out:
# <Axes: ylabel='enmo'>

# %% [markdown]
# - There is no clear linear or strong correlation between anglez and enmo.
# - Both onset and wakeup events are scattered across a wide range of values for both features.
#
# - Several enmo values are greater than zero during the sleep onset phase.
#
# - This indicates that low-level activity may still occur while a person is falling asleep or during sleep, which is consistent with natural body movements.
#
# - Neither anglez nor enmo alone appears sufficient to clearly distinguish between sleep and wake states.
#
# - **Improved sleep state classification may require the combination of multiple features or the inclusion of temporal patterns (e.g., sequences of measurements over time).**

# %% [markdown]
# ## Feature Trasformation

# %%
from sklearn.preprocessing import PowerTransformer

pt = PowerTransformer(method='yeo-johnson')
enmo = pt.fit_transform(data_1[['enmo']]).reshape(1,-1)[0]

# %%
pt = PowerTransformer(method='yeo-johnson')
anglez = pt.fit_transform(data_1[['anglez']]).reshape(1,-1)[0]

# %%
sns.scatterplot(x=anglez,y=enmo,hue=data_1['event'])
# Out:
# <Axes: >

# %% [markdown]
# Even after performing feature transformation, the data distribution remains non-linear and exhibits abnormalities. Therefore, models such as Logistic Regression, Naive Bayes, and Support Vector Machines—which rely on assumptions like linearity or normality—may not perform well. Although K-Nearest Neighbors (KNN) is non-parametric and does not assume a specific distribution, it is still sensitive to irregular or skewed data distributions. As such, KNN is also not suitable in this case.

# %%
data_1 = data_1.with_columns([
    pl.Series("anglez", anglez),
    pl.Series("enmo",enmo)
])
data_1
# Out:
# shape: (9_580, 3)
# ┌───────────┬───────────┬────────┐
# │ anglez    ┆ enmo      ┆ event  │
# │ ---       ┆ ---       ┆ ---    │
# │ f64       ┆ f64       ┆ str    │
# ╞═══════════╪═══════════╪════════╡
# │ -1.574483 ┆ 0.30133   ┆ onset  │
# │ -1.159802 ┆ 1.299062  ┆ wakeup │
# │ 0.144541  ┆ 0.902244  ┆ onset  │
# │ -0.76982  ┆ 0.79776   ┆ wakeup │
# │ 0.247447  ┆ -0.811231 ┆ onset  │
# │ …         ┆ …         ┆ …      │
# │ -1.043835 ┆ -0.273889 ┆ wakeup │
# │ -0.089867 ┆ -0.811231 ┆ onset  │
# │ -0.714734 ┆ -0.811231 ┆ wakeup │
# │ 0.318123  ┆ -0.012355 ┆ onset  │
# │ 1.80742   ┆ -0.811231 ┆ wakeup │
# └───────────┴───────────┴────────┘

# %%
x=data_1[['anglez','enmo']]
y = data_1['event'].to_pandas().map({"onset": 0, "wakeup": 1})

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,f1_score
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=27)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
dt=DecisionTreeClassifier()
rf=RandomForestClassifier()
xgb=XGBClassifier()

# %% [markdown]
# **DecisionTree**

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)
print(accuracy_score(y_test,y_pred))
print(f1_score(y_test,y_pred))
# Out:
# 0.5647181628392485
# 0.5605900948366702

# %% [markdown]
# **RandomForest**

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rf.predict(x_test)
print(accuracy_score(y_test,y_pred))
print(f1_score(y_test,y_pred))
# Out:
# 0.5829853862212944
# 0.5655247417074497

# %%
import optuna

# %%
def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 1000),
        "max_depth": trial.suggest_int("max_depth", 3, 30),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 10),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", None]),
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False]),
    }

    model = RandomForestClassifier(**params, random_state=42)
    model.fit(x_train, y_train)

    preds = model.predict(x_test)
    accuracy = f1_score(y_test, preds)
    return accuracy
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)

print("Best score (accuracy):", study.best_value)
print("Best parameters:", study.best_params)
# Out:
# [I 2025-05-04 09:42:16,891] A new study created in memory with name: no-name-b51e02cc-4815-44f7-989c-c189d4596c21
# [I 2025-05-04 09:42:20,759] Trial 0 finished with value: 0.5751702462022001 and parameters: {'n_estimators': 246, 'max_depth': 27, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': False}. Best is trial 0 with value: 0.5751702462022001.
# [I 2025-05-04 09:42:26,348] Trial 1 finished with value: 0.5940390544707091 and parameters: {'n_estimators': 329, 'max_depth': 25, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 1 with value: 0.5940390544707091.
# [I 2025-05-04 09:42:43,642] Trial 2 finished with value: 0.5845835488877392 and parameters: {'n_estimators': 933, 'max_depth': 30, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': False}. Best is trial 1 with value: 0.5940390544707091.
# [I 2025-05-04 09:42:48,029] Trial 3 finished with value: 0.6064648537711647 and parameters: {'n_estimators': 493, 'max_depth': 27, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 3 with value: 0.6064648537711647.
# [I 2025-05-04 09:42:55,360] Trial 4 finished with value: 0.6110838646395291 and parameters: {'n_estimators': 457, 'max_depth': 19, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': False}. Best is trial 4 with value: 0.6110838646395291.
# [I 2025-05-04 09:43:05,835] Trial 5 finished with value: 0.6106719367588933 and parameters: {'n_estimators': 930, 'max_depth': 13, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 'log2', 'bootstrap': False}. Best is trial 4 with value: 0.6110838646395291.
# [I 2025-05-04 09:43:08,734] Trial 6 finished with value: 0.6605756052992234 and parameters: {'n_estimators': 632, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': False}. Best is trial 6 with value: 0.6605756052992234.
# [I 2025-05-04 09:43:22,261] Trial 7 finished with value: 0.5887850467289719 and parameters: {'n_estimators': 980, 'max_depth': 21, 'min_samples_split': 7, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': False}. Best is trial 6 with value: 0.6605756052992234.
# [I 2025-05-04 09:43:29,328] Trial 8 finished with value: 0.5907915157785825 and parameters: {'n_estimators': 710, 'max_depth': 29, 'min_samples_split': 3, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': True}. Best is trial 6 with value: 0.6605756052992234.
# [I 2025-05-04 09:43:32,360] Trial 9 finished with value: 0.6600938967136151 and parameters: {'n_estimators': 707, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True}. Best is trial 6 with value: 0.6605756052992234.
# [I 2025-05-04 09:43:32,992] Trial 10 finished with value: 0.6599450045829515 and parameters: {'n_estimators': 129, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 6 with value: 0.6605756052992234.
# [I 2025-05-04 09:43:36,140] Trial 11 finished with value: 0.6623012160898035 and parameters: {'n_estimators': 680, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True}. Best is trial 11 with value: 0.6623012160898035.
# [I 2025-05-04 09:43:42,943] Trial 12 finished with value: 0.6392156862745098 and parameters: {'n_estimators': 695, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True}. Best is trial 11 with value: 0.6623012160898035.
# [I 2025-05-04 09:43:49,027] Trial 13 finished with value: 0.6415647921760391 and parameters: {'n_estimators': 631, 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True}. Best is trial 11 with value: 0.6623012160898035.
# [I 2025-05-04 09:43:53,455] Trial 14 finished with value: 0.6657801418439716 and parameters: {'n_estimators': 793, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:44:01,877] Trial 15 finished with value: 0.6324110671936759 and parameters: {'n_estimators': 811, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': True}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:44:12,191] Trial 16 finished with value: 0.6179831097863885 and parameters: {'n_estimators': 827, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:44:21,308] Trial 17 finished with value: 0.648854961832061 and parameters: {'n_estimators': 820, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:44:24,423] Trial 18 finished with value: 0.6657801418439716 and parameters: {'n_estimators': 558, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:44:30,913] Trial 19 finished with value: 0.6230139624458353 and parameters: {'n_estimators': 393, 'max_depth': 12, 'min_samples_split': 3, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:44:38,391] Trial 20 finished with value: 0.6152334152334152 and parameters: {'n_estimators': 548, 'max_depth': 16, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:44:44,211] Trial 21 finished with value: 0.654875283446712 and parameters: {'n_estimators': 587, 'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:44:48,407] Trial 22 finished with value: 0.6657801418439716 and parameters: {'n_estimators': 759, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:44:57,840] Trial 23 finished with value: 0.6472275334608031 and parameters: {'n_estimators': 763, 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:45:02,670] Trial 24 finished with value: 0.6657801418439716 and parameters: {'n_estimators': 870, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:45:07,812] Trial 25 finished with value: 0.6557823129251701 and parameters: {'n_estimators': 525, 'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:45:21,613] Trial 26 finished with value: 0.5907216494845361 and parameters: {'n_estimators': 884, 'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:45:27,096] Trial 27 finished with value: 0.6450094161958568 and parameters: {'n_estimators': 774, 'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:45:29,568] Trial 28 finished with value: 0.6657801418439716 and parameters: {'n_estimators': 443, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:45:35,394] Trial 29 finished with value: 0.5734840698869476 and parameters: {'n_estimators': 267, 'max_depth': 22, 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:45:46,082] Trial 30 finished with value: 0.5933734939759037 and parameters: {'n_estimators': 580, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 9, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:45:50,757] Trial 31 finished with value: 0.6657801418439716 and parameters: {'n_estimators': 847, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:45:58,329] Trial 32 finished with value: 0.6526891522333638 and parameters: {'n_estimators': 905, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:46:04,597] Trial 33 finished with value: 0.6526891522333638 and parameters: {'n_estimators': 746, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:46:10,039] Trial 34 finished with value: 0.6657801418439716 and parameters: {'n_estimators': 984, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:46:16,432] Trial 35 finished with value: 0.647197362223269 and parameters: {'n_estimators': 875, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:46:23,338] Trial 36 finished with value: 0.5968063872255489 and parameters: {'n_estimators': 357, 'max_depth': 18, 'min_samples_split': 2, 'min_samples_leaf': 9, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:46:28,821] Trial 37 finished with value: 0.6526891522333638 and parameters: {'n_estimators': 652, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:46:39,240] Trial 38 finished with value: 0.6 and parameters: {'n_estimators': 783, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:46:53,800] Trial 39 finished with value: 0.5788113695090439 and parameters: {'n_estimators': 936, 'max_depth': 25, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:46:56,038] Trial 40 finished with value: 0.6617982656321314 and parameters: {'n_estimators': 491, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:46:58,110] Trial 41 finished with value: 0.6657801418439716 and parameters: {'n_estimators': 375, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:47:02,177] Trial 42 finished with value: 0.6545619609623241 and parameters: {'n_estimators': 420, 'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:47:04,801] Trial 43 finished with value: 0.6657801418439716 and parameters: {'n_estimators': 463, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:47:10,119] Trial 44 finished with value: 0.6588553402433529 and parameters: {'n_estimators': 739, 'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:47:12,111] Trial 45 finished with value: 0.6499526963103122 and parameters: {'n_estimators': 242, 'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:47:14,225] Trial 46 finished with value: 0.6588553402433529 and parameters: {'n_estimators': 298, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:47:18,622] Trial 47 finished with value: 0.6464354527938343 and parameters: {'n_estimators': 601, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': True}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:47:20,112] Trial 48 finished with value: 0.6529680365296804 and parameters: {'n_estimators': 180, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# [I 2025-05-04 09:47:30,362] Trial 49 finished with value: 0.6446043165467625 and parameters: {'n_estimators': 946, 'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': False}. Best is trial 14 with value: 0.6657801418439716.
# Best score (accuracy): 0.6657801418439716
# Best parameters: {'n_estimators': 793, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': False}

# %%
random_forest_best_params=study.best_params

# %%
random_forest_best_params
# Out:
# {'n_estimators': 793,
#  'max_depth': 3,
#  'min_samples_split': 4,
#  'min_samples_leaf': 7,
#  'max_features': None,
#  'bootstrap': False}

# %% [markdown]
# **XGBoost**

# %%
xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred=xgb.predict(x_test)
print(accuracy_score(y_test,y_pred))
print(f1_score(y_test,y_pred))
# Out:
# 0.6038622129436325
# 0.6313744536182613

# %%
import optuna

# %%
def obj(trial):
    param = {
        "verbosity": 0,
        "objective": "binary:logistic",
        "eval_metric": "logloss",
        "booster": trial.suggest_categorical("booster", ["gbtree", "dart"]),
        "lambda": trial.suggest_loguniform("lambda", 1e-3, 10.0),
        "alpha": trial.suggest_loguniform("alpha", 1e-3, 10.0),
        "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 0.3),
        "n_estimators": trial.suggest_int("n_estimators", 50, 500),
    }

    model = XGBClassifier(**param)
    model.fit(x_train, y_train)

    preds = model.predict(x_test)
    acc = f1_score(y_test, preds)
    return acc

# Run the optimization
study = optuna.create_study(direction="maximize")
study.optimize(obj, n_trials=50)

print("Best trial:")
print(study.best_trial)

print("\nBest hyperparameters:")
print(study.best_params)
# Out:
# [I 2025-05-04 09:50:30,416] A new study created in memory with name: no-name-1515be97-bb08-4fe4-b9d8-cf6905945f12
# [I 2025-05-04 09:50:30,649] Trial 0 finished with value: 0.6390532544378699 and parameters: {'booster': 'gbtree', 'lambda': 0.21555322304034952, 'alpha': 3.6024548063286868, 'subsample': 0.6017996206947007, 'colsample_bytree': 0.731978670623153, 'max_depth': 7, 'learning_rate': 0.01552348902174618, 'n_estimators': 342}. Best is trial 0 with value: 0.6390532544378699.
# [I 2025-05-04 09:50:35,007] Trial 1 finished with value: 0.6366307541625857 and parameters: {'booster': 'dart', 'lambda': 0.0016242525935635328, 'alpha': 0.026081332395231353, 'subsample': 0.6738241095758966, 'colsample_bytree': 0.6671762724049157, 'max_depth': 7, 'learning_rate': 0.024956480946562047, 'n_estimators': 249}. Best is trial 0 with value: 0.6390532544378699.
# [I 2025-05-04 09:50:35,377] Trial 2 finished with value: 0.6267056530214425 and parameters: {'booster': 'gbtree', 'lambda': 0.0013264858951078486, 'alpha': 0.19193300907761307, 'subsample': 0.7512531757252299, 'colsample_bytree': 0.7476946280889889, 'max_depth': 7, 'learning_rate': 0.25267367016342873, 'n_estimators': 443}. Best is trial 0 with value: 0.6390532544378699.
# [I 2025-05-04 09:50:41,151] Trial 3 finished with value: 0.6325036603221084 and parameters: {'booster': 'dart', 'lambda': 0.06498977593011299, 'alpha': 0.036228142630273456, 'subsample': 0.5937831848122493, 'colsample_bytree': 0.9911863535703214, 'max_depth': 5, 'learning_rate': 0.047809596095814796, 'n_estimators': 310}. Best is trial 0 with value: 0.6390532544378699.
# [I 2025-05-04 09:50:41,515] Trial 4 finished with value: 0.6291585127201565 and parameters: {'booster': 'gbtree', 'lambda': 2.692862859234334, 'alpha': 0.26283416060132075, 'subsample': 0.7446323008254263, 'colsample_bytree': 0.7421291463316191, 'max_depth': 8, 'learning_rate': 0.02291289263520592, 'n_estimators': 430}. Best is trial 0 with value: 0.6390532544378699.
# [I 2025-05-04 09:50:49,728] Trial 5 finished with value: 0.6319444444444444 and parameters: {'booster': 'dart', 'lambda': 0.1320529598893599, 'alpha': 8.088187108454463, 'subsample': 0.8583697495615891, 'colsample_bytree': 0.8452083174090026, 'max_depth': 3, 'learning_rate': 0.019154944650058757, 'n_estimators': 363}. Best is trial 0 with value: 0.6390532544378699.
# [I 2025-05-04 09:50:50,086] Trial 6 finished with value: 0.6335766423357664 and parameters: {'booster': 'gbtree', 'lambda': 0.01132715363814741, 'alpha': 0.10673145228059037, 'subsample': 0.8207203093223467, 'colsample_bytree': 0.7547072525169929, 'max_depth': 7, 'learning_rate': 0.10753546717259946, 'n_estimators': 471}. Best is trial 0 with value: 0.6390532544378699.
# [I 2025-05-04 09:50:50,309] Trial 7 finished with value: 0.6422645192776965 and parameters: {'booster': 'gbtree', 'lambda': 0.031867947540630284, 'alpha': 5.2582959266333775, 'subsample': 0.7944875778518246, 'colsample_bytree': 0.6684946731648495, 'max_depth': 9, 'learning_rate': 0.10677068677892115, 'n_estimators': 319}. Best is trial 7 with value: 0.6422645192776965.
# [I 2025-05-04 09:50:50,391] Trial 8 finished with value: 0.6394088669950739 and parameters: {'booster': 'gbtree', 'lambda': 0.3757190383292952, 'alpha': 2.0161713249949775, 'subsample': 0.5505147352458937, 'colsample_bytree': 0.6510058332890443, 'max_depth': 3, 'learning_rate': 0.09798834806334933, 'n_estimators': 177}. Best is trial 7 with value: 0.6422645192776965.
# [I 2025-05-04 09:50:50,512] Trial 9 finished with value: 0.6363191385217817 and parameters: {'booster': 'gbtree', 'lambda': 0.01046938510611466, 'alpha': 0.08755200894890099, 'subsample': 0.7331477979114744, 'colsample_bytree': 0.7417850548530727, 'max_depth': 8, 'learning_rate': 0.0505565208526028, 'n_estimators': 124}. Best is trial 7 with value: 0.6422645192776965.
# [I 2025-05-04 09:50:51,048] Trial 10 finished with value: 0.6268509378084897 and parameters: {'booster': 'dart', 'lambda': 7.583372107265613, 'alpha': 0.001730380594815955, 'subsample': 0.9595964199610794, 'colsample_bytree': 0.5021984195729914, 'max_depth': 10, 'learning_rate': 0.290169716440143, 'n_estimators': 71}. Best is trial 7 with value: 0.6422645192776965.
# [I 2025-05-04 09:50:51,173] Trial 11 finished with value: 0.6387536514118792 and parameters: {'booster': 'gbtree', 'lambda': 0.7553806281846441, 'alpha': 1.4535733921902108, 'subsample': 0.514137850974581, 'colsample_bytree': 0.5813259083035945, 'max_depth': 3, 'learning_rate': 0.10995920356047709, 'n_estimators': 218}. Best is trial 7 with value: 0.6422645192776965.
# [I 2025-05-04 09:50:51,351] Trial 12 finished with value: 0.628009828009828 and parameters: {'booster': 'gbtree', 'lambda': 0.02928308139913105, 'alpha': 1.0218922895576465, 'subsample': 0.8792706132461212, 'colsample_bytree': 0.6055637916820735, 'max_depth': 10, 'learning_rate': 0.10826566235598221, 'n_estimators': 147}. Best is trial 7 with value: 0.6422645192776965.
# [I 2025-05-04 09:50:51,497] Trial 13 finished with value: 0.635340186000979 and parameters: {'booster': 'gbtree', 'lambda': 0.6405168494096958, 'alpha': 8.541884768765767, 'subsample': 0.6382935813675048, 'colsample_bytree': 0.6343577309757885, 'max_depth': 5, 'learning_rate': 0.1699643261003307, 'n_estimators': 221}. Best is trial 7 with value: 0.6422645192776965.
# [I 2025-05-04 09:50:51,636] Trial 14 finished with value: 0.6340508806262231 and parameters: {'booster': 'gbtree', 'lambda': 0.3133796357494778, 'alpha': 0.8148839369444224, 'subsample': 0.5124727959163136, 'colsample_bytree': 0.8496597613794787, 'max_depth': 5, 'learning_rate': 0.070792269981207, 'n_estimators': 172}. Best is trial 7 with value: 0.6422645192776965.
# [I 2025-05-04 09:50:51,907] Trial 15 finished with value: 0.6443474041727317 and parameters: {'booster': 'gbtree', 'lambda': 0.030659273217923347, 'alpha': 2.5598044242576434, 'subsample': 0.990120671831286, 'colsample_bytree': 0.5281339922926704, 'max_depth': 9, 'learning_rate': 0.07312073534192644, 'n_estimators': 287}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:50:52,211] Trial 16 finished with value: 0.6295566502463055 and parameters: {'booster': 'gbtree', 'lambda': 0.005337070672634712, 'alpha': 0.41260191174381133, 'subsample': 0.9900616005801522, 'colsample_bytree': 0.5422545601168414, 'max_depth': 9, 'learning_rate': 0.03501332721897402, 'n_estimators': 295}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:50:52,631] Trial 17 finished with value: 0.6278158667972575 and parameters: {'booster': 'gbtree', 'lambda': 0.03315995108185796, 'alpha': 0.004521677351236408, 'subsample': 0.9202695748219031, 'colsample_bytree': 0.5101625518651002, 'max_depth': 9, 'learning_rate': 0.16833426128936407, 'n_estimators': 389}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:50:58,107] Trial 18 finished with value: 0.63671875 and parameters: {'booster': 'dart', 'lambda': 0.05206072202356391, 'alpha': 3.5775725015456374, 'subsample': 0.818279667644009, 'colsample_bytree': 0.5730266729446807, 'max_depth': 9, 'learning_rate': 0.06903948149397737, 'n_estimators': 268}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:50:58,445] Trial 19 finished with value: 0.6416015625 and parameters: {'booster': 'gbtree', 'lambda': 0.005024205753169811, 'alpha': 3.6605923846760398, 'subsample': 0.9140580987862985, 'colsample_bytree': 0.6831229351149215, 'max_depth': 10, 'learning_rate': 0.0366661271189068, 'n_estimators': 392}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:50:58,749] Trial 20 finished with value: 0.6285993167398731 and parameters: {'booster': 'gbtree', 'lambda': 0.014033305391950962, 'alpha': 0.6157219987457364, 'subsample': 0.7952411766981431, 'colsample_bytree': 0.8202835577273582, 'max_depth': 8, 'learning_rate': 0.17524680735867415, 'n_estimators': 323}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:50:59,088] Trial 21 finished with value: 0.6423001949317739 and parameters: {'booster': 'gbtree', 'lambda': 0.0034040353313080614, 'alpha': 3.446242019035503, 'subsample': 0.9323844784281784, 'colsample_bytree': 0.6856619647830183, 'max_depth': 10, 'learning_rate': 0.03715259656345249, 'n_estimators': 394}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:50:59,322] Trial 22 finished with value: 0.6319444444444444 and parameters: {'booster': 'gbtree', 'lambda': 0.003447240406699485, 'alpha': 9.534243979573265, 'subsample': 0.9992218656481069, 'colsample_bytree': 0.8047825409225623, 'max_depth': 9, 'learning_rate': 0.06921698179824701, 'n_estimators': 494}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:50:59,677] Trial 23 finished with value: 0.6405038759689923 and parameters: {'booster': 'gbtree', 'lambda': 0.015632466236986296, 'alpha': 2.2378539634428156, 'subsample': 0.9435243237860571, 'colsample_bytree': 0.6992564580755358, 'max_depth': 10, 'learning_rate': 0.0332966172593154, 'n_estimators': 381}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:50:59,996] Trial 24 finished with value: 0.6390243902439025 and parameters: {'booster': 'gbtree', 'lambda': 0.0025308146989507464, 'alpha': 4.494272849663518, 'subsample': 0.8541959212203966, 'colsample_bytree': 0.9186989059400427, 'max_depth': 9, 'learning_rate': 0.0759133825353291, 'n_estimators': 416}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:00,287] Trial 25 finished with value: 0.6404328578455485 and parameters: {'booster': 'gbtree', 'lambda': 0.08410397960519746, 'alpha': 1.487907675034577, 'subsample': 0.90178933135646, 'colsample_bytree': 0.6261676956759561, 'max_depth': 8, 'learning_rate': 0.010551831887149992, 'n_estimators': 331}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:04,588] Trial 26 finished with value: 0.635386119257087 and parameters: {'booster': 'dart', 'lambda': 0.03689366149018372, 'alpha': 0.5062163087554571, 'subsample': 0.9640535181487049, 'colsample_bytree': 0.5765458607108241, 'max_depth': 6, 'learning_rate': 0.04214219689159225, 'n_estimators': 259}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:04,813] Trial 27 finished with value: 0.638671875 and parameters: {'booster': 'gbtree', 'lambda': 0.0010134045585649919, 'alpha': 5.277145896869322, 'subsample': 0.7862887130180785, 'colsample_bytree': 0.7859444830577252, 'max_depth': 10, 'learning_rate': 0.13397886799792283, 'n_estimators': 292}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:05,189] Trial 28 finished with value: 0.6345029239766082 and parameters: {'booster': 'gbtree', 'lambda': 0.008055740577187201, 'alpha': 0.012259853901252511, 'subsample': 0.6957414430789178, 'colsample_bytree': 0.699864489824946, 'max_depth': 9, 'learning_rate': 0.08688548094081587, 'n_estimators': 343}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:05,538] Trial 29 finished with value: 0.6436558094312105 and parameters: {'booster': 'gbtree', 'lambda': 0.02111443600705291, 'alpha': 2.614643596310401, 'subsample': 0.9342537210308901, 'colsample_bytree': 0.5423851726524722, 'max_depth': 6, 'learning_rate': 0.053729265423565147, 'n_estimators': 359}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:05,805] Trial 30 finished with value: 0.6301775147928994 and parameters: {'booster': 'gbtree', 'lambda': 0.1114304773788726, 'alpha': 0.28497432288410834, 'subsample': 0.9339380555085388, 'colsample_bytree': 0.5385213574427896, 'max_depth': 6, 'learning_rate': 0.05637284839976578, 'n_estimators': 361}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:06,014] Trial 31 finished with value: 0.6425427872860636 and parameters: {'booster': 'gbtree', 'lambda': 0.02203188045642351, 'alpha': 2.710921112325313, 'subsample': 0.8899590038633649, 'colsample_bytree': 0.6080159229703456, 'max_depth': 4, 'learning_rate': 0.05846548741852158, 'n_estimators': 349}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:06,255] Trial 32 finished with value: 0.6371681415929203 and parameters: {'booster': 'gbtree', 'lambda': 0.019456145322041724, 'alpha': 2.5706669342624755, 'subsample': 0.8875282668617857, 'colsample_bytree': 0.5391869313691653, 'max_depth': 4, 'learning_rate': 0.028920080122004088, 'n_estimators': 413}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:06,519] Trial 33 finished with value: 0.6381738708110734 and parameters: {'booster': 'gbtree', 'lambda': 0.002144984358445306, 'alpha': 1.2865733012663965, 'subsample': 0.9613985998180858, 'colsample_bytree': 0.6080054280076069, 'max_depth': 4, 'learning_rate': 0.05953860625776229, 'n_estimators': 454}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:14,191] Trial 34 finished with value: 0.6331707317073171 and parameters: {'booster': 'dart', 'lambda': 0.005119206007466395, 'alpha': 0.7086178135998866, 'subsample': 0.9820919973381088, 'colsample_bytree': 0.5567580786033558, 'max_depth': 6, 'learning_rate': 0.04636473326707347, 'n_estimators': 349}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:14,340] Trial 35 finished with value: 0.6430678466076696 and parameters: {'booster': 'gbtree', 'lambda': 0.174207853287975, 'alpha': 2.594846576040537, 'subsample': 0.86184073524351, 'colsample_bytree': 0.6034158509838234, 'max_depth': 4, 'learning_rate': 0.026720094607561785, 'n_estimators': 237}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:14,494] Trial 36 finished with value: 0.636 and parameters: {'booster': 'gbtree', 'lambda': 0.061095756084700824, 'alpha': 0.17250756206926582, 'subsample': 0.8566794098373501, 'colsample_bytree': 0.5982359748035395, 'max_depth': 4, 'learning_rate': 0.012660465343780876, 'n_estimators': 239}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:16,834] Trial 37 finished with value: 0.6361829025844931 and parameters: {'booster': 'dart', 'lambda': 0.2612603222113446, 'alpha': 2.356310066101578, 'subsample': 0.8381349539817136, 'colsample_bytree': 0.5156138703275359, 'max_depth': 4, 'learning_rate': 0.018260234082357565, 'n_estimators': 199}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:17,040] Trial 38 finished with value: 0.6390532544378699 and parameters: {'booster': 'gbtree', 'lambda': 0.16810223464231494, 'alpha': 0.07456312380338763, 'subsample': 0.8837778189142474, 'colsample_bytree': 0.6430616868131274, 'max_depth': 5, 'learning_rate': 0.02509908368553097, 'n_estimators': 275}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:17,260] Trial 39 finished with value: 0.640117994100295 and parameters: {'booster': 'gbtree', 'lambda': 1.136185688587789, 'alpha': 6.308406475330521, 'subsample': 0.9055965277581166, 'colsample_bytree': 0.5566738737559579, 'max_depth': 7, 'learning_rate': 0.02132522771306556, 'n_estimators': 288}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:17,422] Trial 40 finished with value: 0.6419386745796242 and parameters: {'booster': 'gbtree', 'lambda': 0.02228156914042727, 'alpha': 1.0452703349165466, 'subsample': 0.7684025109768038, 'colsample_bytree': 0.5316184630540439, 'max_depth': 3, 'learning_rate': 0.015742699345312926, 'n_estimators': 307}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:18,210] Trial 41 finished with value: 0.6421568627450981 and parameters: {'booster': 'gbtree', 'lambda': 0.008667793848849786, 'alpha': 2.521602549116367, 'subsample': 0.9393120770933318, 'colsample_bytree': 0.7127235535116705, 'max_depth': 4, 'learning_rate': 0.04103198627773948, 'n_estimators': 379}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:19,268] Trial 42 finished with value: 0.6398824105830475 and parameters: {'booster': 'gbtree', 'lambda': 0.08742319690534504, 'alpha': 3.943786485465143, 'subsample': 0.968105696985265, 'colsample_bytree': 0.659944820027062, 'max_depth': 5, 'learning_rate': 0.03043041740427902, 'n_estimators': 412}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:19,462] Trial 43 finished with value: 0.6364080039043436 and parameters: {'booster': 'gbtree', 'lambda': 0.060094203706084356, 'alpha': 1.8958824007998403, 'subsample': 0.9341398891083855, 'colsample_bytree': 0.6227788732049182, 'max_depth': 6, 'learning_rate': 0.0554966610063096, 'n_estimators': 240}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:19,677] Trial 44 finished with value: 0.6424361493123772 and parameters: {'booster': 'gbtree', 'lambda': 0.042773279408757366, 'alpha': 6.35886967327489, 'subsample': 0.8741014867841307, 'colsample_bytree': 0.5898680386531826, 'max_depth': 3, 'learning_rate': 0.026432680467973816, 'n_estimators': 443}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:19,891] Trial 45 finished with value: 0.6427870461236507 and parameters: {'booster': 'gbtree', 'lambda': 0.15298308918717632, 'alpha': 5.433524674126906, 'subsample': 0.8711836408462784, 'colsample_bytree': 0.5921275400338958, 'max_depth': 3, 'learning_rate': 0.02645895733496916, 'n_estimators': 464}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:32,277] Trial 46 finished with value: 0.6343612334801763 and parameters: {'booster': 'dart', 'lambda': 0.1745214026616456, 'alpha': 0.023599960670975553, 'subsample': 0.8302153659093446, 'colsample_bytree': 0.5700384835298908, 'max_depth': 3, 'learning_rate': 0.0898453535522896, 'n_estimators': 500}. Best is trial 15 with value: 0.6443474041727317.
# [I 2025-05-04 09:51:32,541] Trial 47 finished with value: 0.6446199407699901 and parameters: {'booster': 'gbtree', 'lambda': 0.5017075930678215, 'alpha': 0.3302015270546656, 'subsample': 0.9011631282811005, 'colsample_bytree': 0.6137937631214214, 'max_depth': 4, 'learning_rate': 0.018919187631972586, 'n_estimators': 475}. Best is trial 47 with value: 0.6446199407699901.
# [I 2025-05-04 09:51:32,841] Trial 48 finished with value: 0.6385896180215475 and parameters: {'booster': 'gbtree', 'lambda': 0.48872944100039123, 'alpha': 0.1554645528578806, 'subsample': 0.7343609967110074, 'colsample_bytree': 0.5215178889711435, 'max_depth': 5, 'learning_rate': 0.017150605195620346, 'n_estimators': 468}. Best is trial 47 with value: 0.6446199407699901.
# [I 2025-05-04 09:51:33,238] Trial 49 finished with value: 0.633692458374143 and parameters: {'booster': 'gbtree', 'lambda': 1.4302983699973504, 'alpha': 0.2814843497431206, 'subsample': 0.8588388837482515, 'colsample_bytree': 0.5520086645396625, 'max_depth': 7, 'learning_rate': 0.021995313606893684, 'n_estimators': 470}. Best is trial 47 with value: 0.6446199407699901.
# Best trial:
# FrozenTrial(number=47, state=1, values=[0.6446199407699901], datetime_start=datetime.datetime(2025, 5, 4, 9, 51, 32, 278613), datetime_complete=datetime.datetime(2025, 5, 4, 9, 51, 32, 540804), params={'booster': 'gbtree', 'lambda': 0.5017075930678215, 'alpha': 0.3302015270546656, 'subsample': 0.9011631282811005, 'colsample_bytree': 0.6137937631214214, 'max_depth': 4, 'learning_rate': 0.018919187631972586, 'n_estimators': 475}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'booster': CategoricalDistribution(choices=('gbtree', 'dart')), 'lambda': FloatDistribution(high=10.0, log=True, low=0.001, step=None), 'alpha': FloatDistribution(high=10.0, log=True, low=0.001, step=None), 'subsample': FloatDistribution(high=1.0, log=False, low=0.5, step=None), 'colsample_bytree': FloatDistribution(high=1.0, log=False, low=0.5, step=None), 'max_depth': IntDistribution(high=10, log=False, low=3, step=1), 'learning_rate': FloatDistribution(high=0.3, log=True, low=0.01, step=None), 'n_estimators': IntDistribution(high=500, log=False, low=50, step=1)}, trial_id=47, value=None)
#
# Best hyperparameters:
# {'booster': 'gbtree', 'lambda': 0.5017075930678215, 'alpha': 0.3302015270546656, 'subsample': 0.9011631282811005, 'colsample_bytree': 0.6137937631214214, 'max_depth': 4, 'learning_rate': 0.018919187631972586, 'n_estimators': 475}

# %%
study.best_value
# Out:
# 0.6446199407699901

# %%
xgb_best_params=study.best_params

# %%
xgb_best_params
# Out:
# {'booster': 'gbtree',
#  'lambda': 0.5017075930678215,
#  'alpha': 0.3302015270546656,
#  'subsample': 0.9011631282811005,
#  'colsample_bytree': 0.6137937631214214,
#  'max_depth': 4,
#  'learning_rate': 0.018919187631972586,
#  'n_estimators': 475}

# %%
xgb = XGBClassifier(**xgb_best_params)

# %%
xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(alpha=0.3302015270546656, base_score=None, booster='gbtree',
#               callbacks=None, colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.6137937631214214, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, lambda=0.5017075930678215,
#               learning_rate=0.018919187631972586, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=475, n_jobs=None, ...)

# %%
y_pred=xgb.predict(x_test)
f1_score(y_test,y_pred)
# Out:
# 0.6446199407699901

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test, y_pred),display_labels=["onset","wakeup"]).plot()
plt.show()

# %%
rf=RandomForestClassifier(**random_forest_best_params)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=3, max_features=None,
#                        min_samples_leaf=7, min_samples_split=4,
#                        n_estimators=793)

# %%
y_pred=rf.predict(x_test)
ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test, y_pred),display_labels=["onset","wakeup"]).plot()
plt.show()

# %% [markdown]
# ## Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
data_2 = df.join(df1[['series_id', 'step', 'event']], on=['series_id', 'step'], how='inner').to_pandas()
data_2 = data_2.sort_values(by=['series_id', 'step'])
data_2 = data_2[['anglez', 'enmo', 'event']]

X = data_2[['anglez', 'enmo']]
y = data_2['event'].map({"onset": 0, "wakeup": 1})  

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=27)

# %%
in_features = ['anglez', 'enmo']
transformer = ColumnTransformer(
    transformers=[
        ('power', PowerTransformer(method='yeo-johnson'), in_features)
    ],
    remainder='passthrough'  
)

pipe = Pipeline([
    ('preprocessing', transformer),
    ('classifier', RandomForestClassifier(**random_forest_best_params)) ]
)

pipe.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('power', PowerTransformer(),
#                                                   ['anglez', 'enmo'])])),
#                 ('classifier',
#                  RandomForestClassifier(bootstrap=False, max_depth=3,
#                                         max_features=None, min_samples_leaf=7,
#                                         min_samples_split=4,
#                                         n_estimators=793))])

# %%
y_pred = pipe.predict(x_test)
print(accuracy_score(y_test,y_pred))
print(f1_score(y_test,y_pred))
# Out:
# 0.6064718162839249
# 0.6657801418439716

# %%
y_pred = pipe.predict(x_test)
print(accuracy_score(y_test,y_pred))
print(f1_score(y_test,y_pred))
# Out:
# 0.6064718162839249
# 0.6657801418439716

# %%
y_pred
# Out:
# array([0, 1, 1, ..., 0, 1, 0])

# %%
import pickle
with open("pipe.pkl",'wb') as file:
    pickle.dump(pipe,file)

# %%
with open('pipe.pkl','rb') as file:
    p=pickle.load(file)

# %%
sample_raw_data=data[:1000]

# %%
sample_raw_data.to_pandas().to_csv("sample_raw_data.csv", index=False, encoding='utf-8-sig')

# %%
sample_event_data=events.clone()

# %%
sample_event_data.to_pandas().to_csv("sample_event_data.csv", index=False, encoding='utf-8-sig')

# %%
sample_event_data
# Out:
# shape: (14_508, 5)
# ┌──────────────┬───────┬────────┬────────┬──────────────────────────┐
# │ series_id    ┆ night ┆ event  ┆ step   ┆ timestamp                │
# │ ---          ┆ ---   ┆ ---    ┆ ---    ┆ ---                      │
# │ str          ┆ i64   ┆ str    ┆ u32    ┆ str                      │
# ╞══════════════╪═══════╪════════╪════════╪══════════════════════════╡
# │ 038441c925bb ┆ 1     ┆ onset  ┆ 4992   ┆ 2018-08-14T22:26:00-0400 │
# │ 038441c925bb ┆ 1     ┆ wakeup ┆ 10932  ┆ 2018-08-15T06:41:00-0400 │
# │ 038441c925bb ┆ 2     ┆ onset  ┆ 20244  ┆ 2018-08-15T19:37:00-0400 │
# │ 038441c925bb ┆ 2     ┆ wakeup ┆ 27492  ┆ 2018-08-16T05:41:00-0400 │
# │ 038441c925bb ┆ 3     ┆ onset  ┆ 39996  ┆ 2018-08-16T23:03:00-0400 │
# │ …            ┆ …     ┆ …      ┆ …      ┆ …                        │
# │ fe90110788d2 ┆ 33    ┆ wakeup ┆ 560604 ┆ 2017-09-06T04:07:00-0400 │
# │ fe90110788d2 ┆ 34    ┆ onset  ┆ 574620 ┆ 2017-09-06T23:35:00-0400 │
# │ fe90110788d2 ┆ 34    ┆ wakeup ┆ 581604 ┆ 2017-09-07T09:17:00-0400 │
# │ fe90110788d2 ┆ 35    ┆ onset  ┆ null   ┆ null                     │
# │ fe90110788d2 ┆ 35    ┆ wakeup ┆ null   ┆ null                     │
# └──────────────┴───────┴────────┴────────┴──────────────────────────┘
